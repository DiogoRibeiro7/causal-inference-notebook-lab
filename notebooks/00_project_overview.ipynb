# %% [markdown]
# # 00 - Project overview
#
# This notebook introduces the causal inference workflow used in the repository.
#
# The main idea is simple: causal inference starts before modelling. We first need to define the causal question, the estimand, and the assumptions that would make the effect identifiable.

# %% [markdown]
# ## Causal question
# What is the causal question this project is answering at a portfolio level?
#
# ## Causal setup
# This overview notebook does not estimate a new effect; it documents the causal workflow used across the project.
#
# ## Estimand
# Core estimand is ATE unless explicitly stated otherwise in each module notebook.
#
# ## Identification assumptions
# No single assumption is introduced here, but each notebook should state exchangeability, positivity, and SUTVA conditions before estimation.

# %% [markdown]
# ## Causal workflow
#
# A good causal analysis should answer these questions:
#
# 1. What is the unit of analysis?
# 2. What is the treatment?
# 3. What is the outcome?
# 4. What is the estimand?
# 5. What assumptions identify the estimand?
# 6. Which estimator is appropriate?
# 7. What diagnostics support the design?
# 8. How sensitive is the conclusion?

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
SRC_PATH = PROJECT_ROOT / "src"
if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Synthetic data with known ground truth
#
# The repository starts with synthetic data. This is useful because we know the true causal effect. We can then see which estimators recover it and which estimators fail.

# %%
from causal_inference_lab import make_confounded_binary_treatment

dataset = make_confounded_binary_treatment(n=5_000, seed=42)
data = dataset.data

print(dataset.description)
print(f"True ATE: {dataset.true_ate:.3f}")
data.head()
# Out:
# Confounded binary treatment with heterogeneous treatment effects.
# True ATE: 1.990
#          x1        x2  x3  treatment   outcome  true_ite  true_propensity
# 0  0.304717 -0.257952   1          1  2.849721  2.152359         0.680226
# 1 -1.039984 -0.299486   0          1  2.699194  1.480008         0.283667
# 2  0.750451 -0.696660   1          1  7.017673  2.375226         0.812001
# 3  0.940565  0.428483   0          0  4.124642  2.470282         0.585786
# 4 -1.951035  0.234646   0          0 -0.954544  1.024482         0.107150

# %% [markdown]
# ## Estimands used in this project
#
# - **ATE:** average treatment effect across all units.
# - **ATT:** average treatment effect among treated units.
# - **CATE:** conditional average treatment effect for a subgroup or covariate profile.
# - **ITE:** individual treatment effect. Usually not directly observable in real data.
#
# The notebooks focus mostly on ATE and CATE.

# %% [markdown]
# ## Portfolio message
#
# This repository is designed to show that you can do more than train predictive models. You can frame causal questions, reason about assumptions, estimate effects, diagnose bias, and communicate uncertainty.

# %% [markdown]
# ## Uncertainty and limitations
# Portfolio-level notebooks are illustrative and synthetic. Effect values are known, but real-world studies need external validity checks, model diagnostics, and uncertainty quantification outside this high-level map.
